# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
t=np.arange(0,2.5,0.1)

# %%
y1 = list(map(math.sin,math.pi*t))
y2 = list(map(math.sin,math.pi*t+math.pi/2))
y3 = list(map(math.sin,math.pi*t-math.pi/2))

# %%
for i in y1:
    print(i)
# Out:
# 0.0
# 0.3090169943749474
# 0.5877852522924731
# 0.8090169943749475
# 0.9510565162951535
# 1.0
# 0.9510565162951535
# 0.8090169943749475
# 0.5877852522924732
# 0.3090169943749475
# 1.2246467991473532e-16
# -0.30901699437494773
# -0.5877852522924734
# -0.8090169943749473
# -0.9510565162951535
# -1.0
# -0.9510565162951536
# -0.809016994374947
# -0.5877852522924734
# -0.3090169943749477
# -2.4492935982947064e-16
# 0.3090169943749472
# 0.5877852522924736
# 0.8090169943749478
# 0.9510565162951538

# %%
plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')
# Out:
# [<matplotlib.lines.Line2D at 0x263a3199f90>,
#  <matplotlib.lines.Line2D at 0x263a3199f60>,
#  <matplotlib.lines.Line2D at 0x263a319be80>]

# %%
plt.plot(t,y1,'b--',t,y2,'g',t,y3,'r-.')
# Out:
# [<matplotlib.lines.Line2D at 0x263aac76500>,
#  <matplotlib.lines.Line2D at 0x263aac764d0>,
#  <matplotlib.lines.Line2D at 0x263aac765f0>]

# %%
plt.plot([1,2,4,2,1,0,1,2,1,4],linewidth=2.0)

# %%
data = {'series1':[1,3,4,3,5],
        'series2':[2,4,5,2,4],
        'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
ax.grid()
t = np.arange(0, 10*np.pi, np.pi/50)
x = np.sin(t)
y = np.cos(t)

ax.plot3D(x, y, t)
ax.set_title('3D Parametric Plot')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('t', labelpad=20)

plt.show()

# %%
fig = plt.figure(figsize = (12,10))
ax = plt.axes(projection='3d')

x = np.arange(-5, 5.1, 0.2)
y = np.arange(-5, 5.1, 0.2)

X, Y = np.meshgrid(x, y)
Z = np.sin(X)*np.cos(Y)

surf = ax.plot_surface(X, Y, Z, cmap = plt.cm.cividis)

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)

fig.colorbar(surf, shrink=0.5, aspect=8)

plt.show()
